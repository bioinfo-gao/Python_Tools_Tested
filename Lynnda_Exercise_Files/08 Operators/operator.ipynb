# %%
5//3
2/3
# Out:
# 0.6666666666666666

# %%
5 % 3
# Out:
# 2

# %%
num =9
num *=5
num
# Out:
# 45

# %%
0b0101 # binary number
# Out:
# 5

# %%
'{:08b}'.format(5)
# Out:
# '00000101'

# %%
x, y = 0x55, 0xAA

print(x , y)
# Out:
# 85 170

# %%
x ^ 0 # exclusive or
# Out:
# 85

# %%
~ x
# Out:
# -86

# %%
6 >= 45
# Out:
# False

# %%
5 == 5
# Out:
# True

# %%
xx=5 
yy=5 
xx is yy
# Out:
# True

# %%
id(xx)
# Out:
# 128620780519792

# %%
id(yy)
# Out:
# 128620780519792

# %%
x, y = [5], [10] # mutable objects
x is y
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
list = range(100)
list[27]
# Out:
# 27

# %%
for i in list[27:43:3]:
    print(i)
# Out:
# 27
# 30
# 33
# 36
# 39
# 42
