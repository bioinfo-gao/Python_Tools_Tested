# %%
x=42
x
# Out:
# 42

# %%
id(x)
# Out:
# 130343387530768

# %%
type(x)
# Out:
# int

# %%
# mutable and immutable ojbect
x=43
id(x)
# Out:
# 130343387530800

# %%
# mutable and immutable ojbect
x=41
id(x)
# Out:
# 130343387530736

# %%
# mutable and immutable ojbect
x=42
id(x)
# Out:
# 130343387530768

# %%
# most fundamental types in python are immutable:
# numbers, strings, tuples
# mutable types:
# lists, dictionaries, sets

# %%
num=42
print(type(num), num)
# Out:
# <class 'int'> 42

# %%
num=42.0
print(type(num), num)
# Out:
# <class 'float'> 42.0

# %%
num = 42/9
print(type(num), num)
# Out:
# <class 'float'> 4.666666666666667

# %%
num=42//9
print(type(num), num)
# Out:
# <class 'int'> 4

# %%
num = 42%9
print(type(num), num)
# Out:
# <class 'int'> 6

# %%
num = int(42/9)
print(type(num), num)
# Out:
# <class 'int'> 4

# %%
# " " or ''  no difference
s1="this is string 1" 
s2='this is string 2'

print(s1)
print(s2)
# Out:
# this is string 1
# this is string 2

# %%
s3="this is \n string 1"
s4=r'this is \n string 2'

print(s3)
print(s4)
# Out:
# this is
#  string 1
# this is \n string 2

# %%
# """ """
# ''' '''
# triple quote

# %%
s5='''
object.ipynb
line
by
line
'''

s6='''\
object.ipynb
line
by
line
'''

# %%
print(s5)
print("===========`")
print(s6)
# Out:
# object.ipynb
# line
# by
# line
#
# ===========`
# object.ipynb
# line
# by
# line

# %%
y=[1,2,3]
y.append(4)
y.insert(0,0)
print(y)
# Out:
# [0, 1, 2, 3, 4]

# %%
d = {"one":1, "two":2, "three":3, "ffour":4, "five":5, "six":6, "seven":7, "eight":8, "nine":9, "ten":10, 
"eleven":11, "twelve":12, "thirteen":13, "fourteen":14, "fifteen":15, "sixteen":16, "seventeen":17, "eighteen":18, "nineteen":19, "twenty":20  }
for k, v in d.items():
    print(k, v)
# Out:
# one 1
# two 2
# three 3
# ffour 4
# five 5
# six 6
# seven 7
# eight 8
# nine 9
# ten 10
# eleven 11
# twelve 12
# thirteen 13
# fourteen 14
# fifteen 15
# sixteen 16
# seventeen 17
# eighteen 18
# nineteen 19
# twenty 20

# %%
for k in sorted(d.keys()):
    print(k, d[k])
# Out:
# eight 8
# eighteen 18
# eleven 11
# ffour 4
# fifteen 15
# five 5
# fourteen 14
# nine 9
# nineteen 19
# one 1
# seven 7
# seventeen 17
# six 6
# sixteen 16
# ten 10
# thirteen 13
# three 3
# twelve 12
# twenty 20
# two 2

# %%
d=dict(
    one = 1, 
    two = 2, 
    three = 3,
    four = 4,
    five = 5
)

# %%
for k in sorted(d.keys()):
    print(k, d[k])
# Out:
# five 5
# four 4
# one 1
# three 3
# two 2

# %%
d['one']
# Out:
# 1
