# %%
# pass

# %%
def main:
    testfunc(42)

def testfunc(number):
    print(number , "from input")

if __name__ == '__main__':
    main()
# Out:
#   Cell In[1], line 1
#
#     def main:
#
#             ^
#
# SyntaxError: invalid syntax
