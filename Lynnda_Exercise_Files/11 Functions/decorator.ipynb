# %%
# pass

# %%
def main():
    testfunc(42)

def testfunc(number):
    print(number , "from input")

if __name__ == '__main__':
    main()
# Out:
# 42 from input

# %%
def main():
    testfunc(42)

def testfunc(number, another = 125, onemore=75):
    print(number , "from input", another, "from another", onemore, 'is the onemore' )

if __name__ == '__main__':
    main()
# Out:
# 42 from input 125 from another 75 is the onemore

# %%
def main():
    testfunc(42)

def testfunc(number, another = None, onemore=75):
    print(number , "from input", another, "from another", onemore, 'is the onemore' )

if __name__ == '__main__':
    main()
# Out:
# 42 from input None from another 75 is the onemore

# %%
def main():
    testfunc(42, 1,2,3)

def testfunc(number, *args):
    print(number , "from input", "and tuple", args )

if __name__ == '__main__':
    main()
# Out:
# 42 from input and tuple (1, 2, 3)

# %%
def main():
    testfunc(5,6,7,8,9,10, one = 42, Two = 2, three = 3)

def testfunc(this, that, other, *args, **kwargs):
    print("this that other from inputs ")
    print("from input are tuple argments ", args) # method 1
    print("from input are tuple argments", args[0], args[1], args[2]) # method 2
    print("from input are key word argments", kwargs['one'], kwargs['Two'], kwargs['three'])

if __name__ == '__main__':
    main()
# Out:
# this that other from inputs
# from input are tuple argments  (8, 9, 10)
# from input are tuple argments 8 9 10
# from input are key word argments 42 2 3

# %%
def main():
    testfunc(one=42, Two=2, three=3)

def testfunc(**kwargs):
    print("from input are key word argments", kwargs['one'], kwargs['Two'], kwargs['three'])

if __name__ == '__main__':
    main()
# Out:
# from input are key word argments 42 2 3
