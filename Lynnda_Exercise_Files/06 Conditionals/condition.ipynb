# %%
def main():
    a,b=1,2
    if a < b:
        print('a is less than b')
    else:
        print('a is not less than b')

if __name__ == "__main__": 
    main()
# Out:
# a is less than b

# %%
a,b=1,2
a < b
# Out:
# True

# %%
def main():
    a,b=1,2
    if True:
        print('a is less than b')
    else:
        print('a is not less than b')

if __name__ == "__main__": 
    main()
# Out:
# a is less than b

# %%
def main():
    a,b=1,2
    if False:
        print('a is less than b')
    else:
        print('a is not less than b')

if __name__ == "__main__": 
    main()
# Out:
# a is not less than b

# %%
def main():
    v='three'
    if v=='one':
        print('v is one')
    elif v=='two':
        print('v is two')
    elif v=='three':
        print('v is three')
    else:
        print('v is not one, two or three')     

if __name__ == "__main__": 
    main()
# Out:
# v is three

# %%
def main():
    choices =  dict(
        one='v is one',
        two='v is two', 
        three='v is three'
    )
    
    v='three'
    print(choices[v])
    v1='seven'
    print(choices.get(v, 'other'))
    print(choices.get(v1, 'other'))

if __name__ == "__main__": 
    main()
# Out:
# v is three
# v is three
# other

# %%
# condiontianl expressions
a,b=0,1
b="a is less than b" if a<b else "a is greater than or equal to b"
print(b)
# Out:
# a is less than b
