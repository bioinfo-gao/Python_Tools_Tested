# %%
def main():
    a,b=1,2
    if a < b:
        print('a is less than b')
    else:
        print('a is not less than b')

if __name__ == "__main__": 
    main()
# Out:
# a is less than b

# %%
def main():
    a,b=1,2
    if True:
        print('a is less than b')
    else:
        print('a is not less than b')

if __name__ == "__main__": 
    main()
# Out:
# a is less than b

# %%
def main():
    a,b=1,2
    if False:
        print('a is less than b')
    else:
        print('a is not less than b')

if __name__ == "__main__": 
    main()
# Out:
# a is not less than b
