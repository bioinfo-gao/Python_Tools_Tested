# %%
def main():
    try:
        fh = open('lines.txt')
        for line in fh: 
            print(line.strip())
    except:
        print('Could not open the file') 
    else:    
        print('File opened successfully')

if __name__ == "__main__": main()
# Out:
# Could not open the file

# %%
# rase is in RED color
# exceptions are in black clor
